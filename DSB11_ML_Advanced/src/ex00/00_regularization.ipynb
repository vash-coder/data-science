# %% [markdown]
# # Day 09. Exercise 00
# # Regularization

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import joblib

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# 1. Read the file `dayofweek.csv` that you used in the previous day to a dataframe.
# 2. Using `train_test_split` with parameters `test_size=0.2`, `random_state=21` get `X_train`, `y_train`, `X_test`, `y_test`. Use the additional parameter `stratify`.

# %%
csv_path = "../data/dayofweek.csv"
df = pd.read_csv(csv_path)

# %%
X = df.drop('dayofweek', axis=1)
y = df['dayofweek']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=21, stratify=y
)

# %% [markdown]
# ## 2. Logreg regularization

# %% [markdown]
# ### a. Default regularization

# %% [markdown]
# 1. Train a baseline model with the only parameters `random_state=21`, `fit_intercept=False`.
# 2. Use stratified K-fold cross-validation with `10` splits to evaluate the accuracy of the model
#
#
# The result of the code where you trained and evaluated the baseline model should be exactly like this (use `%%time` to get the info about how long it took to run the cell):
#
# ```
# train -  0.62902   |   valid -  0.59259
# train -  0.64633   |   valid -  0.62963
# train -  0.63479   |   valid -  0.56296
# train -  0.65622   |   valid -  0.61481
# train -  0.63397   |   valid -  0.57778
# train -  0.64056   |   valid -  0.59259
# train -  0.64138   |   valid -  0.65926
# train -  0.65952   |   valid -  0.56296
# train -  0.64333   |   valid -  0.59701
# train -  0.63674   |   valid -  0.62687
# Average accuracy on crossval is 0.60165
# Std is 0.02943
# ```

# %%
# %%time
model = LogisticRegression(random_state=21, fit_intercept=False)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ### b. Optimizing regularization parameters

# %% [markdown]
# 1. In the cells below try different values of penalty: `none`, `l1`, `l2` – you can change the values of solver too.

# %%
# %%time
model = LogisticRegression(penalty='none', solver='newton-cg', random_state=21, fit_intercept=False)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %%
# %%time
model = LogisticRegression(penalty='l1', solver='liblinear', random_state=21, fit_intercept=False)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %%
# %%time
model = LogisticRegression(penalty='l2', C=0.01, solver='liblinear', random_state=21, fit_intercept=False)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ## 3. SVM regularization

# %% [markdown]
# ### a. Default regularization

# %% [markdown]
# 1. Train a baseline model with the only parameters `probability=True`, `kernel='linear'`, `random_state=21`.
# 2. Use stratified K-fold cross-validation with `10` splits to evaluate the accuracy of the model.
# 3. The format of the result of the code where you trained and evaluated the baseline model should be similar to what you have got for the logreg.

# %%
# %%time
model = SVC(probability=True, kernel='linear', random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ### b. Optimizing regularization parameters

# %% [markdown]
# 1. In the cells below try different values of the parameter `C`.

# %%
# %%time
model = SVC(probability=True, kernel='linear', C=0.1, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %%
# %%time
model = SVC(probability=True, kernel='linear', C=10, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ## 4. Tree

# %% [markdown]
# ### a. Default regularization

# %% [markdown]
# 1. Train a baseline model with the only parameter `max_depth=10` and `random_state=21`.
# 2. Use stratified K-fold cross-validation with `10` splits to evaluate the accuracy of the model.
# 3. The format of the result of the code where you trained and evaluated the baseline model should be similar to what you have got for the logreg.

# %%
# %%time
model = DecisionTreeClassifier(max_depth=10, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ### b. Optimizing regularization parameters

# %% [markdown]
# 1. In the cells below try different values of the parameter `max_depth`.
# 2. As a bonus, play with other regularization parameters trying to find the best combination.

# %%
# %%time
model = DecisionTreeClassifier(max_depth=5, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %%
# %%time
model = DecisionTreeClassifier(max_depth=20, criterion='entropy', random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ## 5. Random forest

# %% [markdown]
# ### a. Default regularization

# %% [markdown]
# 1. Train a baseline model with the only parameters `n_estimators=50`, `max_depth=14`, `random_state=21`.
# 2. Use stratified K-fold cross-validation with `10` splits to evaluate the accuracy of the model.
# 3. The format of the result of the code where you trained and evaluated the baseline model should be similar to what you have got for the logreg.

# %%
# %%time
model = RandomForestClassifier(n_estimators=50, max_depth=14, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ### b. Optimizing regularization parameters

# %% [markdown]
# 1. In the new cells try different values of the parameters `max_depth` and `n_estimators`.
# 2. As a bonus, play with other regularization parameters trying to find the best combination.

# %%
# %%time
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %%
# %%time
model = RandomForestClassifier(n_estimators=200, max_depth=20, random_state=21)

skf = StratifiedKFold(n_splits=10)
accuracies = []

for train_index, valid_index in skf.split(X_train, y_train):
    X_tr, X_val = X_train.iloc[train_index], X_train.iloc[valid_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[valid_index]

    model.fit(X_tr, y_tr)
    train_acc = accuracy_score(y_tr, model.predict(X_tr))
    valid_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"train -  {train_acc:.5f}   |   valid -  {valid_acc:.5f}")
    accuracies.append(valid_acc)

print(f"Average accuracy on crossval is {np.mean(accuracies):.5f}")
print(f"Std is {np.std(accuracies):.5f}")

# %% [markdown]
# ## 6. Predictions

# %% [markdown]
# 1. Choose the best model and use it to make predictions for the test dataset.
# 2. Calculate the final accuracy.
# 3. Analyze: for which weekday your model makes the most errors (in % of the total number of samples of that class in your test dataset).
# 4. Save the model.

# %%
best_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=20,
    random_state=21
)

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

print(f"Final test accuracy: {accuracy_score(y_test, y_pred):.5f}")

# %%
cm = confusion_matrix(y_test, y_pred)
error_rates = (cm.sum(axis=1) - np.diag(cm)) / cm.sum(axis=1) * 100

for day, rate in enumerate(error_rates):
    print(f"Weekday {day}: {rate:.2f}% errors")

worst_day = np.argmax(error_rates)
print(f"\nBiggest errors on weekday: {worst_day} ({error_rates[worst_day]:.2f}%)")

# %%
joblib.dump(best_model, 'best_model.joblib')
print('Model saved')
